# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ====================== advantages of seaborn =====================

# better color combination
# plot direct from the dataframe
# advanced plot(heatmap, kdeplor(key dencity), violinplot, boxplot)
# it has some sample datasets to practice

# %%
penguin_data = sns.load_dataset("penguins")
penguin_data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# scatterplot , stripplot , swarmplot 

# color palette = colorblind , dark , deep , bright

# %%
# sns.scatterplot(data=penguin_data, x="body_mass_g", y="flipper_length_mm", palette="colorblind", hue="sex")

# sns.scatterplot(data=penguin_data, x="body_mass_g", y="flipper_length_mm", palette="deep", hue="sex")
# sns.scatterplot(data=penguin_data, x="body_mass_g", y="flipper_length_mm", palette="dark", hue="sex")
sns.scatterplot(data=penguin_data, x="bill_length_mm", y="bill_depth_mm", palette="bright", hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.stripplot(data=penguin_data, x="island", y="body_mass_g", palette="colorblind", hue="species")
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.stripplot(data=penguin_data, x="sex", y="body_mass_g", palette="colorblind", hue="species")
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
plt.figure(figsize=(12,13))
sns.swarmplot(data=penguin_data, x="sex", y="body_mass_g", palette="colorblind", hue="species")
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
# plt.figure(figsize=(7,8))
# sns.set_context("poster", font_scale=0.4)
# sns.set_context("paper", font_scale=1)
# sns.set_context("notebook")
sns.set_context("talk", font_scale=0.4)
sns.set_style("dark") # dark , white, ticks, darkgrid, whitegrid
sns.swarmplot(data=penguin_data, x="bill_length_mm", y="flipper_length_mm", palette="colorblind", hue="species")
# Out:
# /workspaces/ml/machine-learning/ml-env/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /workspaces/ml/machine-learning/ml-env/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /workspaces/ml/machine-learning/ml-env/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /workspaces/ml/machine-learning/ml-env/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
penguin_data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.boxplot(data=penguin_data, y="body_mass_g", palette="colorblind", hue="species")
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.kdeplot(data=penguin_data, x="bill_length_mm", hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Density'>
