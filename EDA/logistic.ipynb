# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
data = sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# sns.scatterplot(data = data, x = "sepal_length",  y = "sepal_width", hue = "species", palette = "dark")
# sns.scatterplot(data = data, x = "sepal_length",  y = "petal_width", hue = "species", palette = "dark") #It works
# sns.scatterplot(data = data, x = "petal_length",  y = "petal_width", hue = "species", palette = "dark") #It works
sns.scatterplot(data = data, x = "sepal_width",  y = "petal_width", hue = "species", palette = "dark")
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
def numcoded(value):
    if value == "setosa":
        target = 0
    elif value == "versicolor":
        target = 1
    else:
        target = 2
    return target
data["target"] = data["species"].apply(numcoded)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  target
# 0             5.1          3.5           1.4          0.2     setosa       0
# 1             4.9          3.0           1.4          0.2     setosa       0
# 2             4.7          3.2           1.3          0.2     setosa       0
# 3             4.6          3.1           1.5          0.2     setosa       0
# 4             5.0          3.6           1.4          0.2     setosa       0
# ..            ...          ...           ...          ...        ...     ...
# 145           6.7          3.0           5.2          2.3  virginica       2
# 146           6.3          2.5           5.0          1.9  virginica       2
# 147           6.5          3.0           5.2          2.0  virginica       2
# 148           6.2          3.4           5.4          2.3  virginica       2
# 149           5.9          3.0           5.1          1.8  virginica       2
#
# [150 rows x 6 columns]

# %%
x = data.drop(["species", "target", "sepal_length", "sepal_width"], axis = 1)
print(x)

std = StandardScaler()
x_scaled = std.fit_transform(x)
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
y = data["target"]
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_scaled, y, test_size = 0.2, random_state = 36)

# %%
log = LogisticRegression()

# %%
log.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log.predict(X_test)
score = accuracy_score(y_pred, Y_test)

# %%
score
# Out:
# 0.9666666666666667

# %%
Y_test
# Out:
# 50     1
# 145    2
# 86     1
# 118    2
# 122    2
# 57     1
# 56     1
# 51     1
# 69     1
# 66     1
# 59     1
# 4      0
# 110    2
# 94     1
# 29     0
# 35     0
# 28     0
# 77     1
# 14     0
# 146    2
# 48     0
# 125    2
# 102    2
# 27     0
# 131    2
# 115    2
# 42     0
# 147    2
# 96     1
# 128    2
# Name: target, dtype: int64

# %%
con = confusion_matrix(Y_test, y_pred)

# %%
con
# Out:
# array([[ 8,  0,  0],
#        [ 0, 10,  1],
#        [ 0,  0, 11]])

# %%
sns.heatmap(con, annot=True)
# Out:
# <Axes: >

# %%
report = classification_report(Y_test, y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      0.91      0.95        11
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
