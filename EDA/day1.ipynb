# %%
# EDA is the process of identifying the best features that could
# predict our target variable.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamond = sns.load_dataset('diamonds')

# %%
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond.info() #cut color clarity are the categorical
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamond.isnull().sum() 
#Second step is to check if there are null values or not
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamond.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
numeric = diamond.drop(["cut", "color", "clarity"], axis = 1)
numeric
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
corr = numeric.corr()

# %%
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
diamond = diamond.drop(["depth", "table"], axis = 1)

# %%
diamond
# Out:
#        carat        cut color clarity  price     x     y     z
# 0       0.23      Ideal     E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
sns.scatterplot(data = diamond, x = "cut", y = "price", hue = "color", palette = "colorblind")
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.stripplot(data = diamond, x = "cut", y = "price", hue = "color", palette = "colorblind")
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.boxplot(data = diamond, y = "price", hue = "cut")
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(data = diamond, y = "price", hue = "color")
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(data = diamond, y = "price", hue = "clarity")
# Out:
# <Axes: ylabel='price'>

# %%
x = diamond.drop(["color", "clarity", "price"], axis = 1)

# %%
x
y = diamond["price"]

# %%
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
#Feature scaling is a technique where the feature(either categorical or numerical) are
# scaled using multiple scaling techniques that are performed during preprocessing

# %%
arr = np.array([45,34,66,34,567,78,44,33,56,77,44])

# %%
std_arr = arr.std()
mean_arr = arr.mean()

# %%
arr = (arr - mean_arr)/std_arr

arr.mean()
# Out:
# np.float64(1.0092936587501423e-17)

# %%
plt.scatter(diamond["carat"], diamond["price"], color = "red")

# %%
x
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression

# %%
numeric = ["carat", "x", "y", "z"]
categorical = ["cut"]

# %%
clt = ColumnTransformer(
    transformers = [("num", StandardScaler(), numeric),
                    ("cat", OneHotEncoder(), categorical)]
)
x_scaled = clt.fit_transform(x)


x = x.drop(["cut"], axis=1)

# %%
print(x)
print("===============================")
print(y)
# Out:
#        carat     x     y     z
# 0       0.23  3.95  3.98  2.43
# 1       0.21  3.89  3.84  2.31
# 2       0.23  4.05  4.07  2.31
# 3       0.29  4.20  4.23  2.63
# 4       0.31  4.34  4.35  2.75
# ...      ...   ...   ...   ...
# 53935   0.72  5.75  5.76  3.50
# 53936   0.72  5.69  5.75  3.61
# 53937   0.70  5.66  5.68  3.56
# 53938   0.86  6.15  6.12  3.74
# 53939   0.75  5.83  5.87  3.64
#
# [53940 rows x 4 columns]
# ...
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
X_train, X_test, Y_train, Y_test, = train_test_split(x_scaled,y,test_size= 0.2, random_state = 42)

# %%
X_train
X_test
Y_train
Y_test
# Out:
# 1388      559
# 50052    2201
# 41645    1238
# 42377    1304
# 17244    6901
#          ...
# 44081    1554
# 23713     633
# 31375     761
# 21772    9836
# 4998     3742
# Name: price, Length: 10788, dtype: int64

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = lr.predict(X_test)
Y_pred
# Out:
# array([ 318.95147928, 1991.48618406, 1126.03245788, ...,  -80.06785356,
#        7472.21419323, 5696.01613344], shape=(10788,))

# %%
Y_test
# Out:
# 1388      559
# 50052    2201
# 41645    1238
# 42377    1304
# 17244    6901
#          ...
# 44081    1554
# 23713     633
# 31375     761
# 21772    9836
# 4998     3742
# Name: price, Length: 10788, dtype: int64

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
score = r2_score(Y_test, y_pred)

# %%
score
# Out:
# 0.8607489075594825

# %%
m = lr.coef_
b = lr.intercept_

# %%
b
X_train
# Out:
# array([[ 2.55705218,  2.22762827,  2.1499188 , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.44737803,  0.74779811,  0.66146407, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.63724871,  0.76562739,  0.70524215, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.98720039, -1.10644691, -1.11592599, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.21531388,  0.35555397,  0.25870573, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.72163567,  0.9706641 ,  0.92413255, ...,  0.        ,
#          1.        ,  0.        ]], shape=(43152, 9))

# %%
# plt.scatter(X_train[0], Y_train, color = "red")
# plt.plot(X_train[0], m[0] * X_train[0] + b, color = "green")

# %%
plt.scatter(X_test["carat"], Y_test, color = "red")
plt.plot(X_test["carat"], m[0] * X_test["carat"] + b, color = "green")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 plt.scatter(X_test["carat"], Y_test, color = "red")
#       2 plt.plot(X_test["carat"], m[0] * X_test["carat"] + b, color = "green")
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
plt.scatter(Y_test, Y_pred, color="red")
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.show()

# %%
Y_pred = lr.predict(X_test)

plt.figure(figsize=(6,6))
plt.scatter(Y_test, Y_pred)
plt.plot([Y_test.min(), Y_test.max()],
         [Y_test.min(), Y_test.max()],
         color="red")
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted")
plt.show()
